# %% [markdown]
# # Aula 47 - MLP - Reconhecimento de dígitos

# %%
# === 1. Utilitarios mínimos (acurácia, dataset de exemplo, plot e padronização) ===
import numpy as np
import matplotlib.pyplot as plt

def accuracy(y_true, y_pred):
    return float((y_true == y_pred).mean())

def make_moons(n=1000, noise=0.30, seed=0):
    rng = np.random.RandomState(seed)
    angles = rng.rand(n//2) * np.pi
    x1 = np.c_[np.cos(angles), np.sin(angles)]
    x2 = np.c_[np.cos(angles), -np.sin(angles)] + [1.0, 0.4]
    X = np.vstack([x1, x2])
    y = np.r_[np.zeros(n//2, dtype=int), np.ones(n//2, dtype=int)]
    X += rng.normal(scale=noise, size=X.shape)
    return X, y

def train_test_split(X, y, test_size=0.3, seed=0, stratify=True):
    rng = np.random.RandomState(seed)
    n = X.shape[0]
    if stratify:
        tr, te = [], []
        for c in np.unique(y):
            ii = np.where(y == c)[0]
            rng.shuffle(ii)
            t = int(round((1 - test_size) * len(ii)))
            tr.append(ii[:t]); te.append(ii[t:])
        tr = np.concatenate(tr); te = np.concatenate(te)
    else:
        idx = np.arange(n); rng.shuffle(idx)
        t = int(round((1 - test_size) * n))
        tr, te = idx[:t], idx[t:]
    return X[tr], X[te], y[tr], y[te]

def fit_standardizer(X):
    mu = X.mean(axis=0, keepdims=True)
    sd = X.std(axis=0, keepdims=True) + 1e-12
    return mu, sd

def transform_standardizer(X, mu, sd):
    return (X - mu) / sd

def plot_decision_boundary(model, X, y, h=0.03, proba=False, title="Fronteira de decisão"):
    x_min, x_max = X[:,0].min()-0.5, X[:,0].max()+0.5
    y_min, y_max = X[:,1].min()-0.5, X[:,1].max()+0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    grid = np.c_[xx.ravel(), yy.ravel()]
    if proba and hasattr(model, "predict_proba"):
        Z = model.predict_proba(grid)
        if Z.ndim == 2 and Z.shape[1] > 1: Z = Z[:,1]
    else:
        Z = model.predict(grid)
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.contourf(xx, yy, Z, alpha=0.4)
    #plt.scatter(X[:,0], X[:,1], c=y, edgecolor='k')
    plt.title(title); plt.xlabel("x1"); plt.ylabel("x2")
    plt.show()

def plot_lines(xs, ys_dict, xlabel="", ylabel="", title=""):
    plt.figure()
    for label, ys in ys_dict.items():
        plt.plot(xs, ys, marker="o", label=label)
    plt.xlabel(xlabel); plt.ylabel(ylabel); plt.title(title)
    plt.legend(); plt.grid(True, alpha=0.3)
    plt.show()

# %%
# === 2. Regressão logística => OneHiddenMLP (ReLU + Softmax) ===
import numpy as np

#
def _relu(x): return np.maximum(0, x)
def _relu_grad(x): return (x > 0).astype(float)

def _softmax(z):
    z = z - np.max(z, axis=1, keepdims=True)
    exp = np.exp(z)
    return exp / (np.sum(exp, axis=1, keepdims=True) + 1e-12)

class OneHiddenMLP:
    def __init__(self, n_hidden=64, lr=0.05, epochs=40, batch_size=64,
                 l2=1e-4, random_state=0, verbose=False):
        self.n_hidden = n_hidden
        self.lr = lr
        self.epochs = epochs
        self.batch_size = batch_size
        self.l2 = l2
        self.random_state = random_state
        self.verbose = verbose
        self.history_ = {}

    def _init_params(self, n_in, n_out):
        rng = np.random.RandomState(self.random_state)
        W1 = rng.randn(n_in, self.n_hidden) * np.sqrt(2.0 / n_in)
        b1 = np.zeros((1, self.n_hidden))
        W2 = rng.randn(self.n_hidden, n_out) * np.sqrt(2.0 / self.n_hidden)
        b2 = np.zeros((1, n_out))
        self.params_ = {"W1": W1, "b1": b1, "W2": W2, "b2": b2}

    def _forward(self, X):
        W1, b1, W2, b2 = self.params_["W1"], self.params_["b1"], self.params_["W2"], self.params_["b2"]
        z1 = X @ W1 + b1
        h1 = _relu(z1)
        scores = h1 @ W2 + b2
        probs = _softmax(scores)
        return probs, {"X": X, "z1": z1, "h1": h1, "scores": scores, "probs": probs}

    def _loss_and_grads(self, cache, y, n_classes):
        X, z1, h1  = cache["X"], cache["z1"], cache["h1"]
        scores, probs= cache["scores"], cache["probs"]
        m = X.shape[0]
        Y = np.zeros((m, n_classes)); Y[np.arange(m), y.astype(int)] = 1.0
        W1, W2 = self.params_["W1"], self.params_["W2"]

        loss = -np.sum(Y * np.log(probs + 1e-12)) / m + 0.5*self.l2*(np.sum(W1*W1)+np.sum(W2*W2))
        dscores = (probs - Y) / m
        dW2 = h1.T @ dscores + self.l2 * W2
        db2 = np.sum(dscores, axis=0, keepdims=True)
        dh1 = dscores @ W2.T
        dz1 = dh1 * _relu_grad(z1)
        dW1 = X.T @ dz1 + self.l2 * W1
        db1 = np.sum(dz1, axis=0, keepdims=True)
        return loss, {"dW1": dW1, "db1": db1, "dW2": dW2, "db2": db2}

    def fit(self, X, y, X_val=None, y_val=None, early_stopping=False, patience=10):
        n_in = X.shape[1]; n_out = int(np.max(y)) + 1
        self._init_params(n_in, n_out)
        m = X.shape[0]

        hist = {"loss_tr": [], "acc_tr": []}
        if X_val is not None:
            hist.update({"loss_va": [], "acc_va": []})

        best_state = None; best_val = np.inf; wait = 0

        for ep in range(self.epochs):
            idx = np.arange(m); np.random.shuffle(idx)
            for start in range(0, m, self.batch_size):
                batch = idx[start:start+self.batch_size]
                probs, cache = self._forward(X[batch])
                loss, grads = self._loss_and_grads(cache, y[batch], n_out)
                self.params_["W1"] -= self.lr * grads["dW1"]
                self.params_["b1"] -= self.lr * grads["db1"]
                self.params_["W2"] -= self.lr * grads["dW2"]
                self.params_["b2"] -= self.lr * grads["db2"]

            p_tr = self.predict_proba(X); yhat_tr = np.argmax(p_tr, axis=1)
            loss_tr = -np.mean(np.log(p_tr[np.arange(m), y.astype(int)] + 1e-12))
            hist["loss_tr"].append(float(loss_tr))
            hist["acc_tr"].append(float((yhat_tr == y).mean()))

            if X_val is not None:
                pv = self.predict_proba(X_val); yhat_va = np.argmax(pv, axis=1)
                loss_va = -np.mean(np.log(pv[np.arange(X_val.shape[0]), y_val.astype(int)] + 1e-12))
                acc_va = float((yhat_va == y_val).mean())
                hist["loss_va"].append(float(loss_va))
                hist["acc_va"].append(acc_va)

                if early_stopping:
                    if loss_va < best_val - 1e-6:
                        best_val = loss_va
                        best_state = {k: v.copy() for k, v in self.params_.items()}
                        wait = 0
                    else:
                        wait += 1
                        if wait >= patience:
                            if best_state is not None:
                                self.params_ = best_state
                            break

        self.history_ = hist
        return self

    def predict_proba(self, X):
        return self._forward(X)[0]

    def predict(self, X):
        return np.argmax(self.predict_proba(X), axis=1)

    def score(self, X, y):
        return accuracy(y, self.predict(X))

# %%
# 3. Exemplo de treinamento do MLP em moons
X, y = make_moons(n=1200, noise=0.30, seed=42)
Xtr, Xva, ytr, yva = train_test_split(X, y, test_size=0.35, seed=3, stratify=True)

mu, sd = fit_standardizer(Xtr)
Xtr_s = transform_standardizer(Xtr, mu, sd)
Xva_s = transform_standardizer(Xva, mu, sd)

mlp = OneHiddenMLP(n_hidden=64, lr=0.05, epochs=40, batch_size=64, l2=1e-4, random_state=0, verbose=False)
mlp.fit(Xtr_s, ytr, X_val=Xva_s, y_val=yva, early_stopping=True, patience=8)

print("Train acc:", mlp.score(Xtr_s, ytr), "| Val acc:", mlp.score(Xva_s, yva))

epochs = np.arange(1, len(mlp.history_["loss_tr"])+1)
ys = {"loss_tr": mlp.history_["loss_tr"]}
if "loss_va" in mlp.history_: ys["loss_va"] = mlp.history_["loss_va"]
plot_lines(epochs, ys, xlabel="epoch", ylabel="loss", title="Loss vs epoch")

ys2 = {"acc_tr": mlp.history_["acc_tr"]}
if "acc_va" in mlp.history_: ys2["acc_va"] = mlp.history_["acc_va"]
plot_lines(epochs, ys2, xlabel="epoch", ylabel="accuracy", title="Accuracy vs epoch")

plot_decision_boundary(mlp, Xtr_s, ytr, title="MLP (train space, standardized)")
# Out:
# Train acc: 0.8833333333333333 | Val acc: 0.8690476190476191

# %%
# === 4. Varredura de Hiperparametro (width & taxas de aprendizado) ===
import matplotlib.pyplot as plt
widths = [8, 16, 32, 64, 128]
lrs = [0.01, 0.03, 0.05, 0.1]
results = {}

for w in widths:
    vals = []
    for lr in lrs:
        m = OneHiddenMLP(n_hidden=w, lr=lr, epochs=30, batch_size=64, l2=1e-4, random_state=0)
        m.fit(Xtr_s, ytr, X_val=Xva_s, y_val=yva, early_stopping=True, patience=5)
        vals.append(m.score(Xva_s, yva))
    results[f"width={w}"] = vals

plt.figure()
for label, vals in results.items():
    plt.plot(lrs, vals, marker="o", label=label)
plt.xlabel("Taxa de aprendizado"); plt.ylabel("Val accuracy"); plt.title("Val acc vs LR para diferentes larguras")
plt.legend(); plt.grid(True, alpha=0.3)
plt.show()

# %%
# === 5. Teste de gradiente ===
np.random.seed(1)
Xt = Xtr_s[:5]; yt = ytr[:5]
m = OneHiddenMLP(n_hidden=5, lr=0.01, epochs=1, batch_size=5, l2=0.0, random_state=0)
m._init_params(Xt.shape[1], int(np.max(y)+1))

probs, cache = m._forward(Xt)
loss, grads = m._loss_and_grads(cache, yt, int(np.max(y)+1))
print("loss (analítico):", loss)

def loss_only(W2_new):
    P, c = m._forward(Xt)
    m.params_["W2"] = W2_new
    P, c = m._forward(Xt)
    Y = np.zeros((Xt.shape[0], int(np.max(y)+1))); Y[np.arange(Xt.shape[0]), yt] = 1.0
    return -np.sum(Y * np.log(P + 1e-12)) / Xt.shape[0]

W2 = m.params_["W2"].copy()
num = np.zeros_like(W2)
eps = 1e-5
for i in range(W2.shape[0]):
    for j in range(W2.shape[1]):
        W2p = W2.copy(); W2p[i,j] += eps
        W2m = W2.copy(); W2m[i,j] -= eps
        m.params_["W2"] = W2p; lp = loss_only(W2p)
        m.params_["W2"] = W2m; lm = loss_only(W2m)
        num[i,j] = (lp - lm) / (2*eps)
m.params_["W2"] = W2

rel_err = np.linalg.norm(num - grads["dW2"]) / (np.linalg.norm(num) + np.linalg.norm(grads["dW2"]) + 1e-12)
print("Erro relativo (W2):", rel_err)
# Out:
# loss (analítico): 0.2780691057034216
# Erro relativo (W2): 9.82473572549327e-12

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Exemplo

# %%
from sklearn.datasets import fetch_openml
import numpy as np

# Carregue o MNIST dataset
# Demora um pouquinho então evite rodar essa célula desnecessariamente
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)


y = y.astype(int)

print("Formato dos dados de imagem:", X.shape)
print("Formato do array de classes:", y.shape)
# Out:
# Formato dos dados de imagem: (70000, 784)
# Formato do array de classes: (70000,)

# %% [markdown]
# Os dados em X são na verdade dados de imagens. Cada uma das 70000 linhas tem uma imagem (grayscale) de 28x28  pixels (por isso 784). Na célula seguinte vamos visualizar uma delas:

# %%
# @title Rode esse aqui APENAS se o OpenML não estiver funcionando
# Caso o OpenML não esteja funcionando, carregue o arquivo zipado no classroom
# e faça o upload do csv para o workspace

import pandas as pd

# use o pandas pra carregar o csv
df = pd.read_csv('mnist_784.csv')

# Vieram uns NAs de sacanagem
df = df.dropna()

# X são todas colunas menos a ultima
X = df.iloc[:, :-1].values
# y está na ultima coluna do csv
y = df.iloc[:, -1].values.astype(int)

print("Formato dos dados de imagem:", X.shape)
print("Formato do array de classes:", y.shape)
# Out:
# Formato dos dados de imagem: (70000, 784)
# Formato do array de classes: (70000,)

# %%
import matplotlib.pyplot as plt

# Escolhendo uma imagem aleatória
index = 5    # Gerado aleatoriamente com o rolar de um dado balanceado.
single_image = X[index]
single_label = y[index]

# Reshape para tornar a linha com 784 elementos em uma imagem quadrada de 28x28
image_2d = single_image.reshape(28, 28)

# Exibe a imagem
plt.imshow(image_2d, cmap='gray')
plt.title(f"Esse é claramente o dígito: {single_label}")
plt.show()

# %% [markdown]
# Cada linha de X contem uma imagem desse tipo, contendo um dígito e 0 a 9.
#
# Agora, use as funcções que criamos acima para treinar um modelo nesse dado. Ou seja, crie um moelo capaz de reconhecer os dígitos desenhados à mão nas 70000 imagens.

# %% [markdown]
# # Primeiro passo
#
# Os dados estão em uma escala de cinza de 0 a 255.
# Padronize os dados (nesse caso uma simples divisão por 255 funciona bem) e separe um conjunto de treinamento e validação.

# %%
# Padronize os dados
X_scaled = X / 255.0

# Crie um conjunto de treino e validação
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, seed=42, stratify=True)

print(f"Dados de treino: {X_train.shape}")
print(f"Rótulos de treino: {y_train.shape}")
print(f"Dados de validação: {X_val.shape}")
print(f"Rótulos de validação: {y_val.shape}")
# Out:
# Dados de treino: (55999, 784)
# Rótulos de treino: (55999,)
# Dados de validação: (14001, 784)
# Rótulos de validação: (14001,)

# %% [markdown]
# Número de features na entrada = 784
#
# Número de outputs no layer de saída = 10
#
# Esses são fáceis, porém precisamos encontrar um número bom para n_hidden, lr e epochs.

# %%
import matplotlib.pyplot as plt

widths = [16, 32, 64, 128, 256]
lrs = [0.01, 0.03, 0.05, 0.1, 0.15, 0.2]
results = {}


for w in widths:
    vals = []
    for lr in lrs:
        m = OneHiddenMLP(n_hidden=w, lr=lr, epochs=30, batch_size=64, l2=1e-4, random_state=0)
        
        m.fit(X_train, y_train, X_val=X_val, y_val=y_val, early_stopping=True, patience=5)
        
        val_acc = m.score(X_val, y_val)
        vals.append(val_acc)
        print(f"  Width: {w}, LR: {lr} -> Acurácia de Validação: {val_acc*100:.2f}%")
        
    results[f"width={w}"] = vals

plt.figure()
for label, vals in results.items():
    plt.plot(lrs, vals, marker="o", label=label)
    
plt.xlabel("Taxa de aprendizado")
plt.ylabel("Acurácia na Validação")
plt.title("Acurácia vs. Taxa de Aprendizado para diferentes larguras")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
#   Width: 16, LR: 0.01 -> Acurácia de Validação: 93.39%
#   Width: 16, LR: 0.03 -> Acurácia de Validação: 94.78%
#   Width: 16, LR: 0.05 -> Acurácia de Validação: 95.09%
#   Width: 16, LR: 0.1 -> Acurácia de Validação: 95.10%
#   Width: 16, LR: 0.15 -> Acurácia de Validação: 95.15%
#   Width: 16, LR: 0.2 -> Acurácia de Validação: 95.23%
#   Width: 32, LR: 0.01 -> Acurácia de Validação: 94.41%
#   Width: 32, LR: 0.03 -> Acurácia de Validação: 96.07%
#   Width: 32, LR: 0.05 -> Acurácia de Validação: 96.67%
#   Width: 32, LR: 0.1 -> Acurácia de Validação: 96.92%
#   Width: 32, LR: 0.15 -> Acurácia de Validação: 96.85%
#   Width: 32, LR: 0.2 -> Acurácia de Validação: 96.85%
#   Width: 64, LR: 0.01 -> Acurácia de Validação: 95.12%
#   Width: 64, LR: 0.03 -> Acurácia de Validação: 96.91%
#   Width: 64, LR: 0.05 -> Acurácia de Validação: 97.45%
#   Width: 64, LR: 0.1 -> Acurácia de Validação: 97.66%
#   Width: 64, LR: 0.15 -> Acurácia de Validação: 97.55%
#   Width: 64, LR: 0.2 -> Acurácia de Validação: 97.64%
#   Width: 128, LR: 0.01 -> Acurácia de Validação: 95.49%
#   Width: 128, LR: 0.03 -> Acurácia de Validação: 97.41%
#   Width: 128, LR: 0.05 -> Acurácia de Validação: 97.73%
#   Width: 128, LR: 0.1 -> Acurácia de Validação: 97.90%
#   Width: 128, LR: 0.15 -> Acurácia de Validação: 98.04%
#   Width: 128, LR: 0.2 -> Acurácia de Validação: 98.01%
#   Width: 256, LR: 0.01 -> Acurácia de Validação: 95.86%
#   Width: 256, LR: 0.03 -> Acurácia de Validação: 97.56%
#   Width: 256, LR: 0.05 -> Acurácia de Validação: 97.84%
#   Width: 256, LR: 0.1 -> Acurácia de Validação: 98.09%
#   Width: 256, LR: 0.15 -> Acurácia de Validação: 98.11%
#   Width: 256, LR: 0.2 -> Acurácia de Validação: 98.18%

# %%
# Crie seu modelo e avalie sua acurácia

mlp_mnist = OneHiddenMLP(
    n_hidden=256,          
    lr=0.2,
    epochs=40,
    batch_size=64,
    l2=1e-4,
    random_state=42,
    verbose=False
)

# Treina o modelo com os dados de treino e validação
mlp_mnist.fit(X_train, y_train, X_val=X_val, y_val=y_val, early_stopping=True, patience=5)

# Avalia e imprime a acurácia final
acc_train = mlp_mnist.score(X_train, y_train)
acc_val = mlp_mnist.score(X_val, y_val)

print(f"Acurácia final de Treino: {acc_train * 100:.2f}%")
print(f"Acurácia final de Validação: {acc_val * 100:.2f}%")

# Plota os gráficos de loss e acurácia por época
epochs = range(1, len(mlp_mnist.history_["loss_tr"]) + 1)
ys_loss = {"loss_tr": mlp_mnist.history_["loss_tr"], "loss_va": mlp_mnist.history_["loss_va"]}
plot_lines(epochs, ys_loss, xlabel="Época", ylabel="Loss (Custo)", title="Loss vs. Época")

ys_acc = {"acc_tr": mlp_mnist.history_["acc_tr"], "acc_va": mlp_mnist.history_["acc_va"]}
plot_lines(epochs, ys_acc, xlabel="Época", ylabel="Acurácia", title="Acurácia vs. Época")
# Out:
# Acurácia final de Treino: 99.98%
# Acurácia final de Validação: 98.14%

# %%
# Teste alguns elementos aleatórios do conjunto de validação
random_indices = np.random.choice(len(X_val), 5, replace=False)

for index in random_indices:
    image = X_val[index]
    true_label = y_val[index]
    
    
    image_for_prediction = np.expand_dims(image, axis=0)
    predicted_label = mlp_mnist.predict(image_for_prediction)[0]

    
    plt.imshow(image.reshape(28, 28), cmap='gray')
    plt.title(f"Rótulo Verdadeiro: {true_label} | Rótulo Previsto: {predicted_label}")
    plt.show()

# %% [markdown]
# Você pode salvar o seu modelo em um arquivo e carregá-lo novamente em outra sessão sem ter que treiná-lo novamente.
#
# Você também pode testá-lo em seus desenhos feitos na hora em qttt.agdaf.com quando o servidor estiver online.

# %%
import pickle

# escolha o nome do arquivo
filename = 'meu_modelo_alan_diek.pkl'


with open(filename, 'wb') as file:
    # pickle vai guardar o objeto que tem o seu modelo, coloque aqui o nome do seu modelo
    pickle.dump(mlp_mnist, file)

print(f"Modelo salvo em {filename}!")
# Out:
# Modelo salvo em meu_modelo_alan_diek.pkl!

# %% [markdown]
# Para carregar um modelo salvo, use a célula abaixo

# %%
import pickle
import numpy as np

filename = 'meu_modelo_alan_diek.pkl'

with open(filename, 'rb') as file:
    modelocarregado = pickle.load(file)

accuracy = modelocarregado.score(X_val, y_val)
print(f"Acurácia do modelo nos dados de validação: {accuracy * 100:.2f}%")
# Out:
# Acurácia do modelo nos dados de validação: 98.14%
